# %% [markdown]
# ## Using the Boston Dataset-波士頓資料集

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.datasets import load_boston
dataset = load_boston()

# %%
print(dataset.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
print(dataset.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
print(dataset.target)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
#  37.9 32.5 26.4 29.6 50.  32.  29.8 34.9 37.  30.5 36.4 31.1 29.1 50.
#  33.3 30.3 34.6 34.9 32.9 24.1 42.3 48.5 50.  22.6 24.4 22.5 24.4 20.
#  21.7 19.3 22.4 28.1 23.7 25.  23.3 28.7 21.5 23.  26.7 21.7 27.5 30.1
#  44.8 50.  37.6 31.6 46.7 31.5 24.3 31.7 41.7 48.3 29.  24.  25.1 31.5
#  23.7 23.3 22.  20.1 22.2 23.7 17.6 18.5 24.3 20.5 24.5 26.2 24.4 24.8
#  29.6 42.8 21.9 20.9 44.  50.  36.  30.1 33.8 43.1 48.8 31.  36.5 22.8
#  30.7 50.  43.5 20.7 21.1 25.2 24.4 35.2 32.4 32.  33.2 33.1 29.1 35.1
#  45.4 35.4 46.  50.  32.2 22.  20.1 23.2 22.3 24.8 28.5 37.3 27.9 23.9
#  21.7 28.6 27.1 20.3 22.5 29.  24.8 22.  26.4 33.1 36.1 28.4 33.4 28.2
#  22.8 20.3 16.1 22.1 19.4 21.6 23.8 16.2 17.8 19.8 23.1 21.  23.8 23.1
#  20.4 18.5 25.  24.6 23.  22.2 19.3 22.6 19.8 17.1 19.4 22.2 20.7 21.1
#  19.5 18.5 20.6 19.  18.7 32.7 16.5 23.9 31.2 17.5 17.2 23.1 24.5 26.6
#  22.9 24.1 18.6 30.1 18.2 20.6 17.8 21.7 22.7 22.6 25.  19.9 20.8 16.8
#  21.9 27.5 21.9 23.1 50.  50.  50.  50.  50.  13.8 13.8 15.  13.9 13.3
#  13.1 10.2 10.4 10.9 11.3 12.3  8.8  7.2 10.5  7.4 10.2 11.5 15.1 23.2
#   9.7 13.8 12.7 13.1 12.5  8.5  5.   6.3  5.6  7.2 12.1  8.3  8.5  5.
#  11.9 27.9 17.2 27.5 15.  17.2 17.9 16.3  7.   7.2  7.5 10.4  8.8  8.4
#  16.7 14.2 20.8 13.4 11.7  8.3 10.2 10.9 11.   9.5 14.5 14.1 16.1 14.3
#  11.7 13.4  9.6  8.7  8.4 12.8 10.5 17.1 18.4 15.4 10.8 11.8 14.9 12.6
#  14.1 13.  13.4 15.2 16.1 17.8 14.9 14.1 12.7 13.5 14.9 20.  16.4 17.7
#  19.5 20.2 21.4 19.9 19.  19.1 19.1 20.1 19.9 19.6 23.2 29.8 13.8 13.3
#  16.7 12.  14.6 21.4 23.  23.7 25.  21.8 20.6 21.2 19.1 20.6 15.2  7.
#   8.1 13.6 20.1 21.8 24.5 23.1 19.7 18.3 21.2 17.5 16.8 22.4 20.6 23.9
#  22.  11.9]

# %%
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#把target值加上來
df['MEDV'] = dataset.target
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ##  Data Cleansing-資料清洗

# %%
#初步看一下資料
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
#確定一下有沒有空值
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ## Feature Selection-特徵挑選

# %%
#但是透過相關係數的計算，可以先幫我們找到初步的方向，要不然這麼多變數，我要頭昏了!!
corr = df.corr()
print(corr)
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
#---get the top 3 features that has the highest correlation---
#把相關係數最大的三個挑出來

print(df.corr().abs().nlargest(3, 'MEDV').index)

#把三個和'MEDV'相關性最高的值挑出來，所以先做一個filter
print(df.corr().abs().nlargest(3, 'MEDV'))

#把最高三個的相關係數值選出來
print(df.corr().abs().nlargest(3, 'MEDV').values[:,13])
# Out:
# Index(['MEDV', 'LSTAT', 'RM'], dtype='object')
#            CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# MEDV   0.388305  0.360445  0.483725  0.175260  0.427321  0.695360  0.376955
# LSTAT  0.455621  0.412995  0.603800  0.053929  0.590879  0.613808  0.602339
# RM     0.219247  0.311991  0.391676  0.091251  0.302188  1.000000  0.240265
#
#             DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# MEDV   0.249929  0.381626  0.468536  0.507787  0.333461  0.737663  1.000000
# LSTAT  0.496996  0.488676  0.543993  0.374044  0.366087  1.000000  0.737663
# RM     0.205246  0.209847  0.292048  0.355501  0.128069  0.613808  0.695360
# [1.         0.73766273 0.69535995]

# %% [markdown]
# ##  Multiple Regression-多元線性迴歸分析 或是 複線性迴歸

# %%
plt.scatter(df['LSTAT'], df['MEDV'], marker='o',c='r')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %% [markdown]
# LSTAT欄位意思
# ----
# 處於較低地位的人口比例（沒有受過高等教育的成年人的比例以及被歸為勞動者的男性工人比例）。 資料來源：1970年美國人口普查

# %%
plt.scatter(df['RM'], df['MEDV'], marker='o')
plt.xlabel('RM')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %%
#我們現在要導兩個feature進來，所以我們需要3D圖才可以畫出來
fig = plt.figure(figsize=(18,15))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['LSTAT'],
           df['RM'],
           df['MEDV'],
           c='r')

ax.set_xlabel("LSTAT")
ax.set_ylabel("RM")
ax.set_zlabel("MEDV")
plt.show()

# %% [markdown]
# ## Training the Model-訓練模型

# %%
#準備資料
x = pd.DataFrame(df[['LSTAT', 'RM']], columns = ['LSTAT','RM'])
Y = df['MEDV']

# %%
#開分配資料
from sklearn.model_selection import train_test_split
x_train, x_test, Y_train, Y_test = train_test_split(x, Y, test_size = 0.3,random_state=5)

# %%
print(x_train.shape)
print(Y_train.shape)
# Out:
# (354, 2)
# (354,)

# %%
print(x_test.shape)
print(Y_test.shape)
# Out:
# (152, 2)
# (152,)

# %%
#在模型的挑選上，還是同一個

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, Y_train)
# Out:
# LinearRegression()

# %%
#預測結果
price_pred = model.predict(x_test)
price_pred
# Out:
# array([37.1689804 , 29.32035435, 25.58027087,  1.15646598, 33.20707082,
#         8.44197544, 30.37221305, 27.57463198, 26.12976704, 22.01624296,
#        32.13551356, 22.87944818, 22.66492916, 30.77766892, 26.87728603,
#        20.52649771,  0.07700859, 17.73715803, 12.4852138 , 21.5337132 ,
#         5.41730621, 23.83920281, 37.59483142, 24.38880315, 29.45572317,
#        12.97936433, 26.66174451, 22.28532221, 27.15672582, 28.55285561,
#        11.92050914, 10.73457063, 18.04609262, 25.06581211, 26.04950614,
#        22.86501105, 26.1328205 , 12.78655949, 37.06519613, 33.01820965,
#        20.30298129,  1.93992794, 27.34958946, 16.72165643, 27.15469487,
#        29.58123631, -2.17117984, 17.36152288, 20.6656613 , 14.2815521 ,
#        20.69641698, 21.34126367, 24.86153667, 16.4242525 , 17.55536557,
#        27.42110603, 35.81573065, 19.9548413 , 28.51674903, 20.32610396,
#        20.05492026, 22.80452284, 16.55464235, 30.90531655, 22.41792004,
#        13.19072701, 23.32544191, 25.48850806, 22.6711396 , 21.3650088 ,
#        19.39396145, 26.0214486 , 16.76791647, 20.44659086, 19.48139777,
#        29.92580392, 19.25450197, 13.28096308, 28.36799435, 19.04982456,
#        21.99396576, 38.66237215, 16.01409757, 20.37546093, 21.59292711,
#        18.65468385, 17.33399896,  7.78020245, 17.91377663, 23.67759907,
#        35.28845223, 20.08512762, 21.83566663, 19.49200946, 26.14396708,
#        28.36279299, 16.78473924, 30.02853501, 17.87060007, 15.21293924,
#        23.46168625, 25.18928088, 15.82818569, 36.58385184, 15.56792554,
#        23.96708753, 17.93228844, 22.24906929, 25.25833704, 16.07670748,
#        28.00350706, 21.60032302, 20.36009012, 29.04625012, 20.84683004,
#        11.668075  , 18.2418474 , 17.12109486, 18.11674901, 19.16487364,
#        23.09411546, 31.97015914, 26.42198367, 19.75705749, 23.80631329,
#        28.09103094, 21.66647335, 17.31979892, 22.68403467, 36.47723715,
#        36.81706161, 24.25297421, 13.91350713, 17.93002104, 18.10572065,
#        21.52579773, 14.64273606,  4.20981648, 27.14064373, 29.85363551,
#        21.75709542, 20.20380724, 19.03715253, 22.16240367, 31.16575372,
#        22.91516939, 28.86991336, 19.45127925, 23.57354767, 27.76515472,
#        14.62302216, 32.33316572])

# %%
print('R-squared: {:.4f}'.format(model.score(x_test,Y_test)))
# Out:
# R-squared: 0.6162

# %%
#畫一下圖，看看我們預設結果和實際數字的關係
#MSE越小越好，最好趨近於0

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(Y_test, price_pred)
print(mse)

plt.scatter(Y_test, price_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted prices")
plt.title("Actual prices vs Predicted prices")
# Out:
# 36.494221109153244
# Text(0.5, 1.0, 'Actual prices vs Predicted prices')

# %% [markdown]
# ##  Getting the Intercept and Coefficients-拿到截距和斜率

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# 0.38437936780345794
# [-0.65957972  4.83197581]

# %%
print(model.predict([[30,5]]))
# Out:
# [4.75686695]

# %% [markdown]
# ## plot 3D

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston


dataset = load_boston()

df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['MEDV'] = dataset.target

x = df[['LSTAT','RM']]
Y = df['MEDV']

fig = plt.figure(figsize=(18,15))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x['LSTAT'],
           x['RM'],
           Y,
           c='b')

ax.set_xlabel("LSTAT")
ax.set_ylabel("RM")
ax.set_zlabel("MEDV")

#---create a meshgrid of all the values for LSTAT and RM---
x_surf = np.arange(0, 40, 1)   #---for LSTAT---
y_surf = np.arange(0, 10, 1)   #---for RM---
x_surf, y_surf = np.meshgrid(x_surf, y_surf)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, Y)

#---calculate z(MEDC) based on the model---
z = lambda x,y: (model.intercept_ + model.coef_[0] * x + model.coef_[1] * y)

ax.plot_surface(x_surf, y_surf, z(x_surf,y_surf),
                rstride=1,
                cstride=1,
                color='r',
                alpha = 0.4)

plt.show()

# %% [markdown]
# #  <span style="color:red"> Polynomial Regression-多項式回歸

# %%
df = pd.read_csv('polynomial.csv')
df
# Out:
#      x    y
# 0  1.5  1.5
# 1  2.0  2.5
# 2  3.0  4.0
# 3  4.0  4.0
# 4  5.0  4.5
# 5  6.0  5.0

# %%
plt.scatter(df.x,df.y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

x = df.x.values.reshape([-1,1])    #---convert to 2D array---
y = df.y.values.reshape([-1,1]) 

model.fit(x,y)

#---perform prediction---
y_pred = model.predict(x)

#---plot the training points---
plt.scatter(x, y,marker="P", s=50, color='b')

#---plot the straight line---
plt.plot(x, y_pred, color='r')
plt.show()

#---calculate R-squared---
print('R-squared for training set: {:.4f}'.format(model.score(x,y)))
# Out:
# R-squared for training set: 0.8658

# %%
df.x
# Out:
# 0    1.5
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# Name: x, dtype: float64

# %%
#資料要長成這樣，你才有辦法塞給sklearn吃
df.x.values.reshape([-1,1])
# Out:
# array([[1.5],
#        [2. ],
#        [3. ],
#        [4. ],
#        [5. ],
#        [6. ]])

# %% [markdown]
# ##  Polynomial Regression in Scikit-learn-進來看碼

# %%
from sklearn.preprocessing import PolynomialFeatures

degree = 2
polynomial_features = PolynomialFeatures(degree = degree)

# %%
x
# Out:
# array([[1.5],
#        [2. ],
#        [3. ],
#        [4. ],
#        [5. ],
#        [6. ]])

# %%
#我們要透過這個function把我們需要的次方資料準備出來
x_poly = polynomial_features.fit_transform(x)
print(x_poly)
# Out:
# [[ 1.    1.5   2.25]
#  [ 1.    2.    4.  ]
#  [ 1.    3.    9.  ]
#  [ 1.    4.   16.  ]
#  [ 1.    5.   25.  ]
#  [ 1.    6.   36.  ]]

# %%
model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)

#---plot the points---
#s==>scatter的size
plt.scatter(x, y,marker="P", s=50,c='r')

#---plot the regression line---
plt.plot(x, y_poly_pred)
plt.show()

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# [-0.87153912]
# [[ 0.          1.98293207 -0.17239897]]

# %%
#看看這個模型的解釋效果==>非常不錯
print('R-squared for training set: {:.4f}'.format(model.score(x_poly,y)))
# Out:
# R-squared for training set: 0.9474

# %% [markdown]
# ## 導入波士頓房價dataset

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston

dataset = load_boston()

# %% [markdown]
# ##  把dataset整理成(feature+target) skikit learn input 的格式

# %%
#把資料準備成可以餵程式的格式
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['MEDV'] = dataset.target

x = df[['LSTAT','RM']]
Y = df['MEDV']

# %%
#把資料準備成可以餵程式的格式
df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['MEDV'] = dataset.target

x = df[['LSTAT','RM']]
Y = df['MEDV']

# %% [markdown]
# ## 區分成train和test兩組dataset

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, Y_train, Y_test = train_test_split(x, Y, test_size = 0.3,random_state=5)

# %% [markdown]
# ## 準備多項式需要之次方資料

# %%
from sklearn.preprocessing import PolynomialFeatures

#---use a polynomial function of degree 2---
#轉換格式
degree = 2
polynomial_features= PolynomialFeatures(degree = degree)
x_train_poly = polynomial_features.fit_transform(x_train)

# %% [markdown]
# When using a polynomial function of degree 2 on two independent variables x1 and x2, the formula becomes:
#
# ![image.png](attachment:image.png)
#
# where Y is the dependent variable, β0 is the intercept, β1, β2, β3, and β4 are the coefficients of the various combinations of the two features x1 and x2, respectively.

# %%
#---print out the formula---
print(polynomial_features.get_feature_names(['x','y']))
# Out:
# ['1', 'x', 'y', 'x^2', 'x y', 'y^2']

# %% [markdown]
# ## 回歸方程式訓練

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train_poly, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## test dataset測試回歸方程式

# %%
x_test_poly = polynomial_features.fit_transform(x_test)
print('R-squared:{:.4f}'.format(model.score(x_test_poly,Y_test)))
# Out:
# R-squared:0.7340

# %% [markdown]
# ## 模型

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# 26.93343052383921
# [ 0.00000000e+00  1.47424550e+00 -6.70204730e+00  7.93570743e-04
#  -3.66578385e-01  1.17188007e+00]

# %% [markdown]
# With these values, the formula now becomes:
#
# Y = β0 + β1x1 + β2x2 + β3x12 + β4x1x2 +β5x22
#
# Y = 26.9334305238 + 1.47424550e+00 x1 + (-6.70204730e+00) x2 + 7.93570743e-04 x12 + (-3.66578385e-01) x1x2 + 1.17188007e+00 x22

# %% [markdown]
# ## 3D Hyperplane

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_boston

dataset = load_boston()

df = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df['MEDV'] = dataset.target

x = pd.DataFrame(np.c_[df['LSTAT'], df['RM']], columns = ['LSTAT','RM'])
Y = df['MEDV']

fig = plt.figure(figsize=(18,15))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x['LSTAT'],
           x['RM'],
           Y,
           c='b')

ax.set_xlabel("LSTAT")
ax.set_ylabel("RM")
ax.set_zlabel("MEDV")

#---create a meshgrid of all the values for LSTAT and RM---
x_surf = np.arange(0, 40, 1)   #---for LSTAT---
y_surf = np.arange(0, 10, 1)   #---for RM---
x_surf, y_surf = np.meshgrid(x_surf, y_surf)

#---use a polynomial function of degree 2---
degree = 2
polynomial_features= PolynomialFeatures(degree = degree)
x_poly = polynomial_features.fit_transform(x)
print(polynomial_features.get_feature_names(['x','y']))

#---apply linear regression---
model = LinearRegression()
model.fit(x_poly, Y)

#---calculate z(MEDC) based on the model---
z = lambda x,y: (model.intercept_ +
                (model.coef_[1] * x) +
                (model.coef_[2] * y) +
                (model.coef_[3] * x**2) +
                (model.coef_[4] * x*y) +
                (model.coef_[5] * y**2))

ax.plot_surface(x_surf, y_surf, z(x_surf,y_surf),
                rstride=1,
                cstride=1,
                color='None',
                alpha = 0.4)

plt.show()
# Out:
# ['1', 'x', 'y', 'x^2', 'x y', 'y^2']

# %% [markdown]
# #1119545633
